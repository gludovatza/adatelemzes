# %%
a = 5
b = 10
c = a + b
print(c)
# Out:
# 15

# %%
import numpy as np

# %%
B = np.array([
    [12, 7, 3, 8],
    [4, 5, 6, 2],
    [9, 1, 11, 10],
    [14, 0, 13, 15]
])
A = B[::2]
print(A)
# Out:
# [[12  7  3  8]
#  [ 9  1 11 10]]

# %%
even_numbers = A[A % 2 == 0]
print(even_numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 even_numbers = A[A % 2 == 0]
#       2 print(even_numbers)
#
# NameError: name 'A' is not defined
